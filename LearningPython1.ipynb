# %% [markdown]
# ## Learning Python

# %% [markdown]
# Operation 1: Add

# %%
1+1
# Out:
# 2

# %%
print("Hello World")
# Out:
# Hello World

# %%
month1 = 23
month2 = 32
month3 = 65
print((month1+month2+month3)/3)
# Out:
# 40

# %% [markdown]
# $$x = x+2$$

# %%
print(5/3)
# Out:
# 1

# %%
x=25
print(type(x))
# Out:
# <type 'int'>

# %%
pricetxt = "Price : R"
price = 25
print(pricetxt+str(price))
# Out:
# Price : R25

# %% [markdown]
# ## Boolean

# %% [markdown]
# ==, !=, <, >, <=, >=

# %%
print(10!=10)
# Out:
# False

# %%
print(5==5)
# Out:
# True

# %%
print(5>50)
# Out:
# False

# %%
pol_sf, pol_Nu = 864816, 231.89
sf_density = pol_sf/6453682
Nu_density = pol_Nu/486.5

# %%
print(float(sf_density)>float(Nu_density))
# Out:
# False

# %% [markdown]
# ## String

# %%
First_name = "Prishen"
Last_name = "Govender"
print(First_name+" "+Last_name)
# Out:
# Prishen Govender

# %%
x = "10"
y = "20"
z = x+y
print(z)
# Out:
# 1020

# %%
username = "Sameer"
timestamp = "4:50"
url = "http://dut.ac.za"
print(username+" accessed the site "+url+ " at "+timestamp)
# Out:
# Sameer accessed the site http://dut.ac.za at 4:50
